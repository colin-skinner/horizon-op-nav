# %%
import Spice
import importlib

importlib.reload(Spice)
# Out:
# <module 'Spice' from '/Users/magi-nerv/Space-Specifically/Stanford/AA273/horizon-op-nav/Spice.py'>

# %%
file = "data/de442s.bsp"

si = Spice.SpiceImporter()
